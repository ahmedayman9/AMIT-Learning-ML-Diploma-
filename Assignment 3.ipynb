# %% [markdown]
# # Assignment 3

# %% [markdown]
# ### Write a function to count the number 4 in a given list.

# %%
x = [1,2,3,4,4,4,4,4]

def count (*args):
    flag = 0
    for i in x :
        if i == 4 :
            flag+=1
        else :
            continue
    return flag      
z = count()
print(z)
# Out:
# 5

# %% [markdown]
# ### write a  function to check whether a number is divisible by another number.

# %%
x = []

def check (*args):
    for i in range (1,1000000001):
        x.append(i)
        for j in x :            
            if i % j == 0 :
                print(i ,"yes it is divisible by another Number")
            else :
                print(i, "NO it isn't divisible by another Number")

check()
# Out:
# 1 yes it is divisible by another Number
# 2 yes it is divisible by another Number
# 2 yes it is divisible by another Number
# 3 yes it is divisible by another Number
# 3 NO it isn't divisible by another Number
# 3 yes it is divisible by another Number
# 4 yes it is divisible by another Number
# 4 yes it is divisible by another Number
# 4 NO it isn't divisible by another Number
# 4 yes it is divisible by another Number
# 5 yes it is divisible by another Number
# 5 NO it isn't divisible by another Number
# 5 NO it isn't divisible by another Number
# 5 NO it isn't divisible by another Number
# 5 yes it is divisible by another Number
# 6 yes it is divisible by another Number
# 6 yes it is divisible by another Number
# 6 yes it is divisible by another Number
# 6 NO it isn't divisible by another Number
# 6 NO it isn't divisible by another Number
# 6 yes it is divisible by another Number
# 7 yes it is divisible by another Number
# 7 NO it isn't divisible by another Number
# ...

# %% [markdown]
# ### write a function to find the maximum and minimum numbers from a sequence of numbers.

# %%
x = []
def op (*args):
    for i in x :
        op1 = input ("Do you Want to see maximum Or minimum Value ? enter max or min \n \t Or YOu want to Exit enter (yes) for that?").strip()
        if op1 == "max":
            print("the maximum Number in List is : " , max(x))
        elif op1 == "min":
            print("the minimum Number in List is : " , min(x))
        else :
            break
flag = 1
while True and flag >= 1  :
    fun = input ("if you want to continue Enter yes & if you want to stop enter no").strip()
    while fun == 'yes':
        flag +=1 
        inp = int(input("Please Enter your Number : \n "))
        x.append(inp)
        ch  = input ("Do you Want to add more in Your List ? enter yes or no ").strip()
        if ch == "yes":
            continue 
        else:
            op(x)
            print ("Good Bye")
            flag = 0 
            break

    else :
        flag = 0 
else :
    flag = 0  
    print("Thank You")
# Out:
# if you want to continue Enter yes & if you want to stop enter noyes
# Please Enter your Number :
#  1
# Do you Want to add more in Your List ? enter yes or no yes
# Please Enter your Number :
#  2
# Do you Want to add more in Your List ? enter yes or no no
# Do you Want to see maximum Or minimum Value ? enter max or min
#  	 Or YOu want to Exit enter (yes) for that?max
# the maximum Number in List is :  2
# Do you Want to see maximum Or minimum Value ? enter max or min
#  	 Or YOu want to Exit enter (yes) for that?yes
# Good Bye
# Thank You

# %% [markdown]
# ### Write a Python function that takes two lists and returns True if they have at least one common member.

# %%
x = [1,2,3,4,5,6]
y = [7,8,9,10,5,11]
def check (*args):
    for i in x :    
        for j in y :
            if i == j :
                print(True)
check (x,y)
# Out:
# True

# %% [markdown]
# ### Write a Python function to calculate the factorial of a number (a non-negative integer). The function accepts the number from the user

# %%
def factorial (x):
    if x == 1:
        return 1
    else :
        return x *factorial(x-1)
    
x = int(input("Please Enter your Number : \n"))
factorial (x)
# Out:
# Please Enter your Number :
# 5
# 120

# %% [markdown]
# ### Write a Python function to check whether a number is in a given range.
#
# ### The range is from 3 to 11

# %%
def check (x):
    for i in range (3,12):
        if i == x:
            print(True)
x = int(input("Enter Your Number : \n"))
check(x)
# Out:
# Enter Your Number :
# 5
# True

# %% [markdown]
# ### Write a  program to create the multiplication table (from 1 to 10) of a number.

# %%
def mult (x):
    for i in range (1,11):
        z = x*i
        print(x ,"*",i,"=",z )
x= int(input("Enter Your Table Number : \n "))
mult(x)
# Out:
# Enter Your Table Number :
#  5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %% [markdown]
# #### LESSER OF TWO EVENS: Write a function that returns the lesser of two given numbers *if* both numbers are even, but returns the greater if one or both numbers are odd
#     lesser_of_two_evens(2,4) --> 2
#     lesser_of_two_evens(2,5) --> 5

# %%
def ret (*args):
    if x % 2 ==0 and y % 2 ==0 :
        return x,y
    else :
        z.append(x)
        z.append(y)
        return max(z)
z = []

x = int (input("Please Enter Your First Number : \n"))
y = int (input("Please Enter Your Second Number : \n"))
ret(x,y)
# Out:
# Please Enter Your First Number :
# 1
# Please Enter Your Second Number :
# 2
# 2

# %% [markdown]
# #### ANIMAL CRACKERS: Write a function takes a two-word string and returns True if both words begin with same letter
#     animal_crackers('Levelheaded Llama') --> True
#     animal_crackers('Crazy Kangaroo') --> False

# %%
def ret (*args):
    for i in x:
        for j in y :
            if i[0] == j[0]:
                return True 
            else :
                return False 
x = input("Please Enter Your First Word : \n")
y = input("Please Enter Your Second Word : \n")
ret(x,y)
# Out:
# Please Enter Your First Word :
# Ahmed
# Please Enter Your Second Word :
# Ayman
# True

# %% [markdown]
# #### MAKES TWENTY: Given two integers, return True if the sum of the integers is 20 *or* if one of the integers is 20. If not, return False
#
#     makes_twenty(20,10) --> True
#     makes_twenty(12,8) --> True
#     makes_twenty(2,3) --> False

# %%
def ret (*args):
    if x + y == 20 or x ==20 or  y == 20 :
        return True 
    else :
        return False 
x = int(input("Please Enter Your First Num : \n"))
y = int(input("Please Enter Your Second Num : \n"))
ret(x,y)
# Out:
# Please Enter Your First Num :
# 20
# Please Enter Your Second Num :
# 30
# True

# %% [markdown]
# #### ALMOST THERE: Given an integer n, return True if n is within 10 of either 100 or 200
#
#     almost_there(90) --> True
#     almost_there(104) --> True
#     almost_there(150) --> False
#     almost_there(209) --> True
#
# NOTE: `abs(num)` returns the absolute value of a number

# %% [markdown]
# #### BLACKJACK: Given three integers between 1 and 11, if their sum is less than or equal to 21, return their sum. If their sum exceeds 21 *and* there's an eleven, reduce the total sum by 10. Finally, if the sum  exceeds 21, return 'BUST'
#     blackjack(5,6,7) --> 18
#     blackjack(9,9,9) --> 'BUST'
#     blackjack(9,9,11) --> 19
